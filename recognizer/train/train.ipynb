# %%
import os, sys, random, gc
import numpy as np
import pandas as pd
import torch

sys.path.append('../')

from playdict_ocr.tokenization import Tokenizer
from datasets import PartitionedTrainDataset, TrainDataset, TestDataset

tokenizer = Tokenizer()

# %%
class CFG:
    max_dec_len=25
    size=(128, 32)
    epochs, batch_size = 6, 256
    max_grad_norm=4
    embed_dim, attention_dim = 128, 192
    encoder_dim, decoder_dim = 256, 192

# %% [markdown]
# # MODEL

# %%
from models import EncoderDecoderModel
import keras4torch as k4t
from easyocr_model.modules import VGG_FeatureExtractor, ResNet_FeatureExtractor
from repvgg import RepVGG

model = EncoderDecoderModel(
    VGG_FeatureExtractor(1, CFG.encoder_dim),
    #RepVGG(
    #    num_blocks=[2, 4, 6],
    #    width_multiplier=[0.75, 0.75, 0.75],
    #    use_se=False, in_channels=1, output_channels=CFG.encoder_dim),
    CFG, tokenizer)
# Out:
# Encoder: 1388416
# Decoder: 1144004

# %%
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence

class CollateWrapper:
    # run on cpu
    def __call__(self, batch):
        src, tgt, tgt_lens = [], [], []
        for t in batch:
            src.append(t[0])
            tgt.append(torch.from_numpy(t[1]))
            tgt_lens.append(t[2])

        src = torch.stack(src)
        tgt = pad_sequence(tgt, batch_first=True, padding_value=0)
        tgt_lens = torch.tensor(tgt_lens, dtype=torch.int64)
        return src, tgt, tgt_lens, torch.tensor(0)

# %%
class MyLoopConfig(k4t.configs.TrainerLoopConfig):
    # run on gpu
    def process_batch(self, batch):
        src, tgt, tgt_lens, _ = batch
        if not self.training:
            return (src,), tgt

        tgt_lens, sort_idx = tgt_lens.sort(dim=0, descending=True)
        src, tgt = src[sort_idx], tgt[sort_idx]
        return (src, tgt, tgt_lens), tgt

    def prepare_for_optimizer_step(self, model):
        torch.nn.utils.clip_grad_norm_(model.model.encoder.parameters(), CFG.max_grad_norm)
        torch.nn.utils.clip_grad_norm_(model.model.decoder.parameters(), CFG.max_grad_norm)

# %%
from torch.optim.lr_scheduler import OneCycleLR
import torch.nn as nn
import torch.nn.functional as F
from torch_optimizer import AdaBelief

class CombinedOpt(torch.optim.Optimizer):
    def __init__(self, model):
        super().__init__(model.parameters(), {'lr': float('-inf')})
        self.encoder_opt = AdaBelief(
            model.encoder.parameters(), lr=1e-4)
        self.decoder_opt = torch.optim.Adam(
            model.decoder.parameters(), lr=4e-4)

    def step(self):
        self.encoder_opt.step()
        self.decoder_opt.step()

opt = CombinedOpt(model)

model = k4t.Model(model)

def ce_loss(y_pred, y_true):
    y_pred = y_pred.reshape(-1, tokenizer.vocab_size)
    y_true = y_true.reshape(-1)
    nonzero_indices = torch.nonzero(y_true).view(-1)
    return F.cross_entropy(y_pred[nonzero_indices], y_true[nonzero_indices])

def acc(y_pred, y_true):
    y_pred = y_pred.argmax(-1).cpu().numpy()
    y_true = y_true.cpu().numpy()

    y_ = [(tokenizer.indices_to_string(i) == tokenizer.indices_to_string(j))
            for i,j in zip(y_pred, y_true)]

    return torch.tensor(y_, dtype=float).mean()

model.compile(optimizer=opt, loss=ce_loss, metrics=[acc], loop_config=MyLoopConfig(), disable_val_loss=True)

# %%
file_list = [f"../preprocessed/train_data_{i}.pkl" for i in range(4)]
cnt_list = [2000000] * 3 + [1224600]

val_data = pd.read_pickle("../preprocessed/val_data.pkl")

train_set = PartitionedTrainDataset(file_list, cnt_list, tokenizer, CFG.size)
val_set = TrainDataset(val_data, tokenizer, CFG.size)

# %% [markdown]
# # Train loop

# %%
from torch.utils.data import DataLoader
from keras4torch.callbacks import LRScheduler
import pickle
from keras4torch.utils.data import RestrictedRandomSampler
from keras4torch.callbacks import ModelCheckpoint

torch.backends.cudnn.benchmark = True

model.fit(train_set,
            validation_data=val_set,
            epochs=CFG.epochs,
            batch_size=CFG.batch_size,
            validation_batch_size=CFG.batch_size*2,
            collate_fn=CollateWrapper(),
            sampler=RestrictedRandomSampler(cnt_list),
            callbacks=[ModelCheckpoint('saved_model/best.pt', monitor='val_acc')]
)

# %%
model.model.deploy()

model.load_weights('saved_model/best.pt')

_ = torch.onnx.export(model.model.cpu(),
    val_set[0][0].unsqueeze_(0), "saved_model/vgg_lstm.onnx", verbose=True, opset_version=11, input_names=['x'], output_names=['sequence'])
# Out:
#  %decoder.decode_step.cells.0.weight_ih, %decoder.decode_step.cells.0.bias_ih)
#   %2305 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2238, %decoder.decode_step.cells.0.weight_hh, %decoder.decode_step.cells.0.bias_hh) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2306 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Add(%2305, %2304) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2307 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2308 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2309 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2310 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[192, 192, 192, 192]](%2306) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2311 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2307) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2312 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2308) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2313 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2309) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2314 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2310) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2315 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2311, %2313)
#   %2316 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2312, %2236) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2317 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Add(%2316, %2315) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2318 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2317) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2319 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2314, %2318) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2320 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2303, %decoder.decode_step.cells.1.weight_ih, %decoder.decode_step.cells.1.bias_ih)
#   %2321 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2319, %decoder.decode_step.cells.1.weight_hh, %decoder.decode_step.cells.1.bias_hh) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2322 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Add(%2321, %2320) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2323 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2324 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2325 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2326 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[192, 192, 192, 192]](%2322) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2327 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2323) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2328 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2324) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2329 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2325) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2330 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2326) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2331 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2327, %2329)
#   %2332 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2328, %2317) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2333 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Add(%2332, %2331) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2334 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2333) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2335 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2330, %2334) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2336 : Float(1, 67, strides=[67, 1], requires_grad=0, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2335, %decoder.fc.weight, %decoder.fc.bias) # g:\playdict\recognizer\train\models.py:121:0
#   %2337 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={23}]()
#   %2338 : Float(*, *, strides=[1675, 1], requires_grad=0, device=cpu) = onnx::Gather[axis=1](%2282, %2337) # g:\playdict\recognizer\train\models.py:122:0
#   %2339 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2338)
#   %2340 : Float(1, 67, strides=[67, 1], requires_grad=0, device=cpu) = onnx::Expand(%2336, %2339) # g:\playdict\recognizer\train\models.py:122:0
#   %2341 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2282)
#   %2342 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2343 : Long(device=cpu) = onnx::Gather[axis=0](%2341, %2342)
#   %2344 : Long(device=cpu) = onnx::Cast[to=7](%2343)
#   %2345 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2346 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %2347 : Long(*, device=cpu) = onnx::Range(%2345, %2344, %2346)
#   %2349 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %2350 : Long(*, 1, device=cpu) = onnx::Reshape(%2347, %2349)
#   %2353 : Long(*, 1, device=cpu) = onnx::Add(%2350, %2582)
#   %2354 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2353)
#   %2355 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2354)
#   %2356 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%2355)
#   %2357 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2358 : Long(*, device=cpu) = onnx::Mul(%2356, %2357)
#   %2359 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%2354, %2358)
#   %2360 : Long(2, strides=[1], device=cpu) = onnx::Where(%2359, %2356, %2354)
#   %2361 : LongTensor(device=cpu) = onnx::Expand(%2350, %2360)
#   %2362 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%2361)
#   %2363 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2354)
#   %2364 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%2363)
#   %2365 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2366 : Long(*, device=cpu) = onnx::Mul(%2364, %2365)
#   %2367 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%2354, %2366)
#   %2368 : Long(2, strides=[1], device=cpu) = onnx::Where(%2367, %2364, %2354)
#   %2369 : LongTensor(device=cpu) = onnx::Expand(%2582, %2368)
#   %2370 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%2369)
#   %2371 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%2362, %2370)
#   %2372 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2282)
#   %2373 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %2374 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %2375 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %2376 : Long(1, strides=[1], device=cpu) = onnx::Slice(%2372, %2374, %2375, %2373)
#   %2377 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%2354, %2376)
#   %2378 : FloatTensor(device=cpu) = onnx::Reshape(%2340, %2377)
#   %2379 : Float(*, *, *, strides=[1675, 67, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%2282, %2371, %2378) # g:\playdict\recognizer\train\models.py:122:0
#   %2380 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::ArgMax[axis=-1, keepdims=0](%2336) # g:\playdict\recognizer\train\models.py:124:0
#   %2381 : Float(1, 128, strides=[128, 1], requires_grad=1, device=cpu) = onnx::Gather(%decoder.embedding.weight, %2380) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1916:0
#   %2383 : Float(1, 31, 192, strides=[5952, 192, 1], requires_grad=1, device=cpu) = onnx::MatMul(%75, %2583) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2384 : Float(1, 31, 192, strides=[5952, 192, 1], requires_grad=1, device=cpu) = onnx::Add(%2383, %decoder.attention.encoder_att.bias) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2385 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2335, %decoder.attention.decoder_att.weight, %decoder.attention.decoder_att.bias) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2386 : Float(1, 1, 192, strides=[192, 192, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%2385) # g:\playdict\recognizer\train\models.py:21:0
#   %2387 : Float(1, 31, 192, strides=[5952, 192, 1], requires_grad=1, device=cpu) = onnx::Add(%2384, %2386) # g:\playdict\recognizer\train\models.py:22:0
#   %2388 : Float(1, 31, 192, strides=[5952, 192, 1], requires_grad=1, device=cpu) = onnx::Relu(%2387) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1204:0
#   %2390 : Float(1, 31, 1, strides=[31, 1, 1], requires_grad=1, device=cpu) = onnx::MatMul(%2388, %2584) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2391 : Float(1, 31, 1, strides=[31, 1, 1], requires_grad=1, device=cpu) = onnx::Add(%2390, %decoder.attention.full_att.1.bias) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2392 : Float(1, 1, 31, strides=[31, 31, 1], device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%2391)
#   %2393 : Float(1, 1, 31, strides=[31, 31, 1], device=cpu) = onnx::Softmax[axis=2](%2392)
#   %2394 : Float(1, 31, 1, strides=[31, 1, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%2393) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1583:0
#   %2395 : Float(1, 31, 256, strides=[7936, 256, 1], requires_grad=1, device=cpu) = onnx::Mul(%75, %2394) # g:\playdict\recognizer\train\models.py:23:0
#   %2396 : Float(1, 256, strides=[256, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[1], keepdims=0](%2395) # g:\playdict\recognizer\train\models.py:23:0
#   %2397 : Float(1, 256, strides=[256, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2335, %decoder.fc_gate.0.weight, %decoder.fc_gate.0.bias) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2398 : Float(1, 256, strides=[256, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2397)
#   %2399 : Float(1, 256, strides=[256, 1], requires_grad=1, device=cpu) = onnx::Mul(%2396, %2398) # g:\playdict\recognizer\train\models.py:114:0
#   %2400 : Float(1, 384, strides=[384, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%2381, %2399) # g:\playdict\recognizer\train\models.py:117:0
#   %2401 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2400, %decoder.decode_step.cells.0.weight_ih, %decoder.decode_step.cells.0.bias_ih)
#   %2402 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2335, %decoder.decode_step.cells.0.weight_hh, %decoder.decode_step.cells.0.bias_hh) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2403 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Add(%2402, %2401) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2404 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2405 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2406 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2407 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[192, 192, 192, 192]](%2403) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2408 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2404) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2409 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2405) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2410 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2406) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2411 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2407) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2412 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2408, %2410)
#   %2413 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2409, %2333) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2414 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Add(%2413, %2412) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2415 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2414) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2416 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2411, %2415) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2417 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2400, %decoder.decode_step.cells.1.weight_ih, %decoder.decode_step.cells.1.bias_ih)
#   %2418 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2416, %decoder.decode_step.cells.1.weight_hh, %decoder.decode_step.cells.1.bias_hh) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2419 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Add(%2418, %2417) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2420 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2421 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2422 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2423 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[192, 192, 192, 192]](%2419) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2424 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2420) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2425 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2421) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2426 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2422) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2427 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2423) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2428 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2424, %2426)
#   %2429 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2425, %2414) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2430 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Add(%2429, %2428) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2431 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2430) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2432 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2427, %2431) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2433 : Float(1, 67, strides=[67, 1], requires_grad=0, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2432, %decoder.fc.weight, %decoder.fc.bias) # g:\playdict\recognizer\train\models.py:121:0
#   %2434 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={24}]()
#   %2435 : Float(*, *, strides=[1675, 1], requires_grad=0, device=cpu) = onnx::Gather[axis=1](%2379, %2434) # g:\playdict\recognizer\train\models.py:122:0
#   %2436 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2435)
#   %2437 : Float(1, 67, strides=[67, 1], requires_grad=0, device=cpu) = onnx::Expand(%2433, %2436) # g:\playdict\recognizer\train\models.py:122:0
#   %2438 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2379)
#   %2439 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2440 : Long(device=cpu) = onnx::Gather[axis=0](%2438, %2439)
#   %2441 : Long(device=cpu) = onnx::Cast[to=7](%2440)
#   %2442 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2443 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %2444 : Long(*, device=cpu) = onnx::Range(%2442, %2441, %2443)
#   %2446 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %2447 : Long(*, 1, device=cpu) = onnx::Reshape(%2444, %2446)
#   %2450 : Long(*, 1, device=cpu) = onnx::Add(%2447, %2586)
#   %2451 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2450)
#   %2452 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2451)
#   %2453 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%2452)
#   %2454 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2455 : Long(*, device=cpu) = onnx::Mul(%2453, %2454)
#   %2456 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%2451, %2455)
#   %2457 : Long(2, strides=[1], device=cpu) = onnx::Where(%2456, %2453, %2451)
#   %2458 : LongTensor(device=cpu) = onnx::Expand(%2447, %2457)
#   %2459 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%2458)
#   %2460 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2451)
#   %2461 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%2460)
#   %2462 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2463 : Long(*, device=cpu) = onnx::Mul(%2461, %2462)
#   %2464 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%2451, %2463)
#   %2465 : Long(2, strides=[1], device=cpu) = onnx::Where(%2464, %2461, %2451)
#   %2466 : LongTensor(device=cpu) = onnx::Expand(%2586, %2465)
#   %2467 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%2466)
#   %2468 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%2459, %2467)
#   %2469 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2379)
#   %2470 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %2471 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %2472 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %2473 : Long(1, strides=[1], device=cpu) = onnx::Slice(%2469, %2471, %2472, %2470)
#   %2474 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%2451, %2473)
#   %2475 : FloatTensor(device=cpu) = onnx::Reshape(%2437, %2474)
#   %2476 : Float(*, *, *, requires_grad=0, device=cpu) = onnx::ScatterND(%2379, %2468, %2475)
#   %sequence : Long(*, *, strides=[25, 1], requires_grad=0, device=cpu) = onnx::ArgMax[axis=-1, keepdims=0](%2476) # g:\playdict\recognizer\train\models.py:173:0
#   return (%sequence)
