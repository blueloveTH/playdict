# %%
import os, sys, random, gc
import numpy as np
import pandas as pd
import torch

sys.path.append('../')

from playdict_ocr.tokenization import Tokenizer
from datasets import PartitionedTrainDataset, TrainDataset, TestDataset

tokenizer = Tokenizer()

# %%
class CFG:
    max_dec_len=25
    size=(128, 32)
    epochs, batch_size = 6, 256
    max_grad_norm=4
    embed_dim, attention_dim = 128, 192
    encoder_dim, decoder_dim = 256, 192

# %% [markdown]
# # MODEL

# %%
from models import EncoderDecoderModel
import keras4torch as k4t
from easyocr_model.modules import VGG_FeatureExtractor, ResNet_FeatureExtractor
from repvgg import RepVGG

model = EncoderDecoderModel(
    VGG_FeatureExtractor(1, CFG.encoder_dim),
    #RepVGG(
    #    num_blocks=[2, 4, 6],
    #    width_multiplier=[0.75, 0.75, 0.75],
    #    use_se=False, in_channels=1, output_channels=CFG.encoder_dim),
    CFG, tokenizer)
# Out:
# Encoder: 1388416
# Decoder: 1144004

# %%
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence

class CollateWrapper:
    # run on cpu
    def __call__(self, batch):
        src, tgt, tgt_lens = [], [], []
        for t in batch:
            src.append(t[0])
            tgt.append(torch.from_numpy(t[1]))
            tgt_lens.append(t[2])

        src = torch.stack(src)
        tgt = pad_sequence(tgt, batch_first=True, padding_value=0)
        tgt_lens = torch.tensor(tgt_lens, dtype=torch.int64)
        return src, tgt, tgt_lens, torch.tensor(0)

# %%
class MyLoopConfig(k4t.configs.TrainerLoopConfig):
    # run on gpu
    def process_batch(self, batch):
        src, tgt, tgt_lens, _ = batch
        if not self.training:
            return (src,), tgt

        tgt_lens, sort_idx = tgt_lens.sort(dim=0, descending=True)
        src, tgt = src[sort_idx], tgt[sort_idx]
        return (src, tgt, tgt_lens), tgt

    def prepare_for_optimizer_step(self, model):
        torch.nn.utils.clip_grad_norm_(model.model.encoder.parameters(), CFG.max_grad_norm)
        torch.nn.utils.clip_grad_norm_(model.model.decoder.parameters(), CFG.max_grad_norm)

# %%
from torch.optim.lr_scheduler import OneCycleLR
import torch.nn as nn
import torch.nn.functional as F
from torch_optimizer import AdaBelief

class CombinedOpt(torch.optim.Optimizer):
    def __init__(self, model):
        super().__init__(model.parameters(), {'lr': float('-inf')})
        self.encoder_opt = AdaBelief(
            model.encoder.parameters(), lr=1e-4)
        self.decoder_opt = torch.optim.Adam(
            model.decoder.parameters(), lr=4e-4)

    def step(self):
        self.encoder_opt.step()
        self.decoder_opt.step()

opt = CombinedOpt(model)

model = k4t.Model(model)

def ce_loss(y_pred, y_true):
    y_pred = y_pred.reshape(-1, tokenizer.vocab_size)
    y_true = y_true.reshape(-1)
    nonzero_indices = torch.nonzero(y_true).view(-1)
    return F.cross_entropy(y_pred[nonzero_indices], y_true[nonzero_indices])

def acc(y_pred, y_true):
    y_pred = y_pred.argmax(-1).cpu().numpy()
    y_true = y_true.cpu().numpy()

    y_ = [(tokenizer.indices_to_string(i) == tokenizer.indices_to_string(j))
            for i,j in zip(y_pred, y_true)]

    return torch.tensor(y_, dtype=float).mean()

model.compile(optimizer=opt, loss=ce_loss, metrics=[acc], loop_config=MyLoopConfig(), disable_val_loss=True)

# %%
file_list = [f"../preprocessed/train_data_{i}.pkl" for i in range(4)]
cnt_list = [2000000] * 3 + [1224600]

val_data = pd.read_pickle("../preprocessed/val_data.pkl")

train_set = PartitionedTrainDataset(file_list, cnt_list, tokenizer, CFG.size)
val_set = TrainDataset(val_data, tokenizer, CFG.size)

# %% [markdown]
# # Train loop

# %%
from torch.utils.data import DataLoader
from keras4torch.callbacks import LRScheduler
import pickle
from keras4torch.utils.data import RestrictedRandomSampler
from keras4torch.callbacks import ModelCheckpoint

torch.backends.cudnn.benchmark = True

model.fit(train_set,
            validation_data=val_set,
            epochs=CFG.epochs,
            batch_size=CFG.batch_size,
            validation_batch_size=CFG.batch_size*2,
            collate_fn=CollateWrapper(),
            sampler=RestrictedRandomSampler(cnt_list),
            callbacks=[ModelCheckpoint('saved_model/best.pt', monitor='val_acc')]
)
# Out:
# Train on 7224600 samples, validate on 802733 samples:
# Epoch 1/4
#   181/28222 [..............................] - ETA: 1:07:03 - loss: 2.9050 - acc: 0.0000e+00

# %%
model.load_weights('saved_model/best.pt')

_ = torch.onnx.export(model.model.cpu(),
    val_set[0][0].unsqueeze_(0), "saved_model/vgg_lstm.onnx", verbose=True, opset_version=11, input_names=['x'])
# Out:
# \train\models.py:116:0
#   %2296 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2295, %decoder.decode_step.cells.0.weight_ih, %decoder.decode_step.cells.0.bias_ih)
#   %2297 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2230, %decoder.decode_step.cells.0.weight_hh, %decoder.decode_step.cells.0.bias_hh) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2298 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Add(%2297, %2296) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2299 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2300 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2301 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2302 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[192, 192, 192, 192]](%2298) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2303 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2299) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2304 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2300) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2305 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2301) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2306 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2302) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2307 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2303, %2305)
#   %2308 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2304, %2228) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2309 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Add(%2308, %2307) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2310 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2309) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2311 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2306, %2310) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2312 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2295, %decoder.decode_step.cells.1.weight_ih, %decoder.decode_step.cells.1.bias_ih)
#   %2313 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2311, %decoder.decode_step.cells.1.weight_hh, %decoder.decode_step.cells.1.bias_hh) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2314 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Add(%2313, %2312) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2315 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2316 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2317 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2318 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[192, 192, 192, 192]](%2314) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2319 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2315) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2320 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2316) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2321 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2317) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2322 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2318) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2323 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2319, %2321)
#   %2324 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2320, %2309) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2325 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Add(%2324, %2323) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2326 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2325) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2327 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2322, %2326) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2328 : Float(1, 67, strides=[67, 1], requires_grad=0, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2327, %decoder.fc.weight, %decoder.fc.bias) # g:\playdict\recognizer\train\models.py:120:0
#   %2329 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={23}]()
#   %2330 : Float(*, *, strides=[1675, 1], requires_grad=0, device=cpu) = onnx::Gather[axis=1](%2274, %2329) # g:\playdict\recognizer\train\models.py:121:0
#   %2331 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2330)
#   %2332 : Float(1, 67, strides=[67, 1], requires_grad=0, device=cpu) = onnx::Expand(%2328, %2331) # g:\playdict\recognizer\train\models.py:121:0
#   %2333 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2274)
#   %2334 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2335 : Long(device=cpu) = onnx::Gather[axis=0](%2333, %2334)
#   %2336 : Long(device=cpu) = onnx::Cast[to=7](%2335)
#   %2337 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2338 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %2339 : Long(*, device=cpu) = onnx::Range(%2337, %2336, %2338)
#   %2341 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %2342 : Long(*, 1, device=cpu) = onnx::Reshape(%2339, %2341)
#   %2345 : Long(*, 1, device=cpu) = onnx::Add(%2342, %2572)
#   %2346 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2345)
#   %2347 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2346)
#   %2348 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%2347)
#   %2349 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2350 : Long(*, device=cpu) = onnx::Mul(%2348, %2349)
#   %2351 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%2346, %2350)
#   %2352 : Long(2, strides=[1], device=cpu) = onnx::Where(%2351, %2348, %2346)
#   %2353 : LongTensor(device=cpu) = onnx::Expand(%2342, %2352)
#   %2354 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%2353)
#   %2355 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2346)
#   %2356 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%2355)
#   %2357 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2358 : Long(*, device=cpu) = onnx::Mul(%2356, %2357)
#   %2359 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%2346, %2358)
#   %2360 : Long(2, strides=[1], device=cpu) = onnx::Where(%2359, %2356, %2346)
#   %2361 : LongTensor(device=cpu) = onnx::Expand(%2572, %2360)
#   %2362 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%2361)
#   %2363 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%2354, %2362)
#   %2364 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2274)
#   %2365 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %2366 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %2367 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %2368 : Long(1, strides=[1], device=cpu) = onnx::Slice(%2364, %2366, %2367, %2365)
#   %2369 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%2346, %2368)
#   %2370 : FloatTensor(device=cpu) = onnx::Reshape(%2332, %2369)
#   %2371 : Float(*, *, *, strides=[1675, 67, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%2274, %2363, %2370) # g:\playdict\recognizer\train\models.py:121:0
#   %2372 : Long(1, strides=[1], requires_grad=0, device=cpu) = onnx::ArgMax[axis=-1, keepdims=0](%2328) # g:\playdict\recognizer\train\models.py:123:0
#   %2373 : Float(1, 128, strides=[128, 1], requires_grad=1, device=cpu) = onnx::Gather(%decoder.embedding.weight, %2372) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1916:0
#   %2375 : Float(1, 31, 192, strides=[5952, 192, 1], requires_grad=1, device=cpu) = onnx::MatMul(%67, %2573) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2376 : Float(1, 31, 192, strides=[5952, 192, 1], requires_grad=1, device=cpu) = onnx::Add(%2375, %decoder.attention.encoder_att.bias) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2377 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2327, %decoder.attention.decoder_att.weight, %decoder.attention.decoder_att.bias) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2378 : Float(1, 1, 192, strides=[192, 192, 1], requires_grad=1, device=cpu) = onnx::Unsqueeze[axes=[1]](%2377) # g:\playdict\recognizer\train\models.py:20:0
#   %2379 : Float(1, 31, 192, strides=[5952, 192, 1], requires_grad=1, device=cpu) = onnx::Add(%2376, %2378) # g:\playdict\recognizer\train\models.py:21:0
#   %2380 : Float(1, 31, 192, strides=[5952, 192, 1], requires_grad=1, device=cpu) = onnx::Relu(%2379) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1204:0
#   %2382 : Float(1, 31, 1, strides=[31, 1, 1], requires_grad=1, device=cpu) = onnx::MatMul(%2380, %2574) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2383 : Float(1, 31, 1, strides=[31, 1, 1], requires_grad=1, device=cpu) = onnx::Add(%2382, %decoder.attention.full_att.1.bias) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2384 : Float(1, 1, 31, strides=[31, 31, 1], device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%2383)
#   %2385 : Float(1, 1, 31, strides=[31, 31, 1], device=cpu) = onnx::Softmax[axis=2](%2384)
#   %2386 : Float(1, 31, 1, strides=[31, 1, 1], requires_grad=1, device=cpu) = onnx::Transpose[perm=[0, 2, 1]](%2385) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1583:0
#   %2387 : Float(1, 31, 256, strides=[7936, 256, 1], requires_grad=1, device=cpu) = onnx::Mul(%67, %2386) # g:\playdict\recognizer\train\models.py:22:0
#   %2388 : Float(1, 256, strides=[256, 1], requires_grad=1, device=cpu) = onnx::ReduceSum[axes=[1], keepdims=0](%2387) # g:\playdict\recognizer\train\models.py:22:0
#   %2389 : Float(1, 256, strides=[256, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2327, %decoder.fc_gate.0.weight, %decoder.fc_gate.0.bias) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\functional.py:1753:0
#   %2390 : Float(1, 256, strides=[256, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2389)
#   %2391 : Float(1, 256, strides=[256, 1], requires_grad=1, device=cpu) = onnx::Mul(%2388, %2390) # g:\playdict\recognizer\train\models.py:113:0
#   %2392 : Float(1, 384, strides=[384, 1], requires_grad=1, device=cpu) = onnx::Concat[axis=1](%2373, %2391) # g:\playdict\recognizer\train\models.py:116:0
#   %2393 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2392, %decoder.decode_step.cells.0.weight_ih, %decoder.decode_step.cells.0.bias_ih)
#   %2394 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2327, %decoder.decode_step.cells.0.weight_hh, %decoder.decode_step.cells.0.bias_hh) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2395 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Add(%2394, %2393) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2396 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2397 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2398 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2399 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[192, 192, 192, 192]](%2395) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2400 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2396) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2401 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2397) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2402 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2398) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2403 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2399) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2404 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2400, %2402)
#   %2405 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2401, %2325) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2406 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Add(%2405, %2404) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2407 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2406) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2408 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2403, %2407) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2409 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2392, %decoder.decode_step.cells.1.weight_ih, %decoder.decode_step.cells.1.bias_ih)
#   %2410 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2408, %decoder.decode_step.cells.1.weight_hh, %decoder.decode_step.cells.1.bias_hh) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2411 : Float(1, 768, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Add(%2410, %2409) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2412 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2413 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2414 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu), %2415 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Split[axis=1, split=[192, 192, 192, 192]](%2411) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2416 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2412) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2417 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2413) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2418 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2414) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2419 : Float(1, 192, strides=[768, 1], requires_grad=1, device=cpu) = onnx::Sigmoid(%2415) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2420 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2416, %2418)
#   %2421 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2417, %2406) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2422 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Add(%2421, %2420) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2423 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Tanh(%2422) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2424 : Float(1, 192, strides=[192, 1], requires_grad=1, device=cpu) = onnx::Mul(%2419, %2423) # D:\miniconda\envs\data_science\lib\site-packages\torch\nn\modules\rnn.py:1054:0
#   %2425 : Float(1, 67, strides=[67, 1], requires_grad=0, device=cpu) = onnx::Gemm[alpha=1., beta=1., transB=1](%2424, %decoder.fc.weight, %decoder.fc.bias) # g:\playdict\recognizer\train\models.py:120:0
#   %2426 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={24}]()
#   %2427 : Float(*, *, strides=[1675, 1], requires_grad=0, device=cpu) = onnx::Gather[axis=1](%2371, %2426) # g:\playdict\recognizer\train\models.py:121:0
#   %2428 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2427)
#   %2429 : Float(1, 67, strides=[67, 1], requires_grad=0, device=cpu) = onnx::Expand(%2425, %2428) # g:\playdict\recognizer\train\models.py:121:0
#   %2430 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2371)
#   %2431 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2432 : Long(device=cpu) = onnx::Gather[axis=0](%2430, %2431)
#   %2433 : Long(device=cpu) = onnx::Cast[to=7](%2432)
#   %2434 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2435 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %2436 : Long(*, device=cpu) = onnx::Range(%2434, %2433, %2435)
#   %2438 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %2439 : Long(*, 1, device=cpu) = onnx::Reshape(%2436, %2438)
#   %2442 : Long(*, 1, device=cpu) = onnx::Add(%2439, %2576)
#   %2443 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2442)
#   %2444 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2443)
#   %2445 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%2444)
#   %2446 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2447 : Long(*, device=cpu) = onnx::Mul(%2445, %2446)
#   %2448 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%2443, %2447)
#   %2449 : Long(2, strides=[1], device=cpu) = onnx::Where(%2448, %2445, %2443)
#   %2450 : LongTensor(device=cpu) = onnx::Expand(%2439, %2449)
#   %2451 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%2450)
#   %2452 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2443)
#   %2453 : Long(*, device=cpu) = onnx::ConstantOfShape[value={1}](%2452)
#   %2454 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2455 : Long(*, device=cpu) = onnx::Mul(%2453, %2454)
#   %2456 : Bool(2, strides=[1], device=cpu) = onnx::Equal(%2443, %2455)
#   %2457 : Long(2, strides=[1], device=cpu) = onnx::Where(%2456, %2453, %2443)
#   %2458 : LongTensor(device=cpu) = onnx::Expand(%2576, %2457)
#   %2459 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%2458)
#   %2460 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%2451, %2459)
#   %2461 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2371)
#   %2462 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %2463 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %2464 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %2465 : Long(1, strides=[1], device=cpu) = onnx::Slice(%2461, %2463, %2464, %2462)
#   %2466 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%2443, %2465)
#   %2467 : FloatTensor(device=cpu) = onnx::Reshape(%2429, %2466)
#   %2468 : Float(*, *, *, strides=[1675, 67, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%2371, %2460, %2467)
#   return (%2468)
